# %%
# execute master script
exec(open("./ta_master.py").read())

# %%
# example activities for testing
account_activity(5000,date = pd.Timestamp(2017,1,1))
account_activity(1000,date = pd.Timestamp(2017,2,1))
account_activity(-500,date = pd.Timestamp(2017,3,1))
account_activity(5,comment='Adjustment',date = pd.Timestamp(2017,4,1))
buy('Share1',2000,10,date = pd.Timestamp(2017,5,1))
update(Share1=2050,date = pd.Timestamp(2017,6,1))
buy('Share2',2000,10,date = pd.Timestamp(2017,7,1))
update(Share1=2040,Share2=2020,date = pd.Timestamp(2017,8,1))
update(date = pd.Timestamp(2017,9,1))
dividend('Share1',200,date = pd.Timestamp(2017,9,1))
update(Share1=2070,Share2=2100,date = pd.Timestamp(2017,10,1))
sell('Share1',2060,date = pd.Timestamp(2017,10,1))
account_activity(-3,comment='Mistake',date = pd.Timestamp(2017,11,1))
delete_last_row()
backup()
# Out:
# Share name already exists. No changes made.
# Share name already exists. No changes made.
# Given share name is not an active share, no action taken.
# Given share name is not an active share, no action taken.
# Backed up trading account and deleted last row.

# %%
# display all data
t_all = all_values(all_shares=True)
t_all
# Out:
#          Date  Acct Bal          Comment                   Share1  \
# 0  2017-01-01      5000  Opening deposit          nan (0.00,0.00)
# 1  2017-02-01      6000          Deposit          nan (0.00,0.00)
# 2  2017-03-01      5500       Withdrawal          nan (0.00,0.00)
# 3  2017-04-01      5505       Adjustment          nan (0.00,0.00)
# 4  2017-05-01      3495       Buy Share1       nan (2000.00,0.00)
# 5  2017-06-01      3495           Update    0.1744 (2050.00,0.00)
# 6  2017-07-01      1485       Buy Share2    0.1744 (2050.00,0.00)
# 7  2017-08-01      1485           Update    0.0393 (2040.00,0.00)
# 8  2017-09-01      1485           Update    0.0294 (2040.00,0.00)
# 9  2017-09-01      1685  Dividend Share1  0.3082 (2040.00,200.00)
# 10 2017-10-01      1685           Update  0.2797 (2070.00,200.00)
# 11 2017-10-01      3745      Sell Share1          nan (0.00,0.00)
# 12 2017-01-01      8745          Deposit          nan (0.00,0.00)
# 13 2017-02-01      9745          Deposit          nan (0.00,0.00)
# 14 2017-03-01      9245       Withdrawal          nan (0.00,0.00)
# 15 2017-04-01      9250       Adjustment          nan (0.00,0.00)
# 16 2017-06-01      9250           Update          nan (0.00,0.00)
# 17 2017-08-01      9250           Update          nan (0.00,0.00)
# 18 2017-09-01      9250           Update          nan (0.00,0.00)
# 19 2017-10-01      9250           Update          nan (0.00,0.00)
#
#                    Share2
# 0         nan (0.00,0.00)
# 1         nan (0.00,0.00)
# 2         nan (0.00,0.00)
# 3         nan (0.00,0.00)
# 4         nan (0.00,0.00)
# 5         nan (0.00,0.00)
# 6      nan (2000.00,0.00)
# 7   0.0000 (2020.00,0.00)
# 8   0.0000 (2020.00,0.00)
# 9   0.0000 (2020.00,0.00)
# 10  0.1548 (2100.00,0.00)
# 11  0.1548 (2100.00,0.00)
# 12  0.1548 (2100.00,0.00)
# 13  0.1548 (2100.00,0.00)
# 14  0.1548 (2100.00,0.00)
# 15  0.1548 (2100.00,0.00)
# 16  0.1548 (2100.00,0.00)
# 17  0.0000 (2020.00,0.00)
# 18  0.0000 (2020.00,0.00)
# 19  0.1548 (2100.00,0.00)

# %%
# plot share values over time
t_shr = shr_values(all_shares=True)
t_shr.plot()

# %%
# time series of total value of the account
tv = total_value()
tv
# Out:
#             Total Value
# Date
# 2017-01-01         5000
# 2017-02-01         6000
# 2017-03-01         5500
# 2017-04-01         5505
# 2017-05-01         5485
# 2017-06-01         5535
# 2017-07-01         5515
# 2017-08-01         5525
# 2017-09-01         5525
# 2017-09-01         5725
# 2017-10-01         5835
# 2017-10-01         5835
# 2017-01-01        10835
# 2017-02-01        11835
# 2017-03-01        11335
# 2017-04-01        11340
# 2017-06-01        11340
# 2017-08-01        11260
# 2017-09-01        11260
# 2017-10-01        11340

# %%
# list active shares
active_shares()
# Out:
# ['Share2']

# %%
# bond evaluation tool
be = bond_evaluation(5,1)
be
# Out:
#                  Price
# Return (%)
# -1.0        106.060606
# -0.5        105.527638
#  0.0        105.000000
#  0.5        104.477612
#  1.0        103.960396
#  1.5        103.448276
#  2.0        102.941176
#  2.5        102.439024
#  3.0        101.941748
#  3.5        101.449275
#  4.0        100.961538
#  4.5        100.478469
#  5.0        100.000000
#  5.5         99.526066
#  6.0         99.056604
#  6.5         98.591549
#  7.0         98.130841
#  7.5         97.674419
#  8.0         97.222222
#  8.5         96.774194
#  9.0         96.330275
#  9.5         95.890411
